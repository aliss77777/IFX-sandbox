# %%
#!pip install fastkml
# Out:
# Collecting fastkml
#   Downloading fastkml-1.1.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: arrow in /opt/anaconda3/lib/python3.12/site-packages (from fastkml) (1.2.3)
# Collecting pygeoif>=1.5 (from fastkml)
#   Downloading pygeoif-1.5.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions>4 in /opt/anaconda3/lib/python3.12/site-packages (from fastkml) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from arrow->fastkml) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7.0->arrow->fastkml) (1.16.0)
# Downloading fastkml-1.1.0-py3-none-any.whl (107 kB)
# Downloading pygeoif-1.5.1-py3-none-any.whl (28 kB)
# Installing collected packages: pygeoif, fastkml
# Successfully installed fastkml-1.1.0 pygeoif-1.5.1

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.12/site-packages (5.2.1)

# %%
import xml.etree.ElementTree as ET
import csv
import os
import sys
from xml.dom import minidom

def extract_kml_to_csv(kml_path, csv_path):
    print(f"Attempting to read KML file from: {os.path.abspath(kml_path)}")
    
    # Check if file exists and is readable
    if not os.path.exists(kml_path):
        print(f"ERROR: The KML file does not exist at {os.path.abspath(kml_path)}")
        return False
    
    if not os.access(kml_path, os.R_OK):
        print(f"ERROR: The KML file exists but is not readable. Check permissions.")
        return False
    
    # Analyze the file structure first
    print("Analyzing KML file structure...")
    try:
        with open(kml_path, 'r', encoding='utf-8') as f:
            content = f.read()
            print(f"File size: {len(content)} bytes")
            
            # Print a sample of the content to help debug
            sample = content[:500]
            print(f"First 500 characters of file: {sample}")
            
            # Check if it contains typical KML elements
            has_kml_tag = '<kml' in content
            has_placemark = '<Placemark' in content
            has_document = '<Document' in content
            has_folder = '<Folder' in content
            
            print(f"Has KML tag: {has_kml_tag}")
            print(f"Has Placemark tags: {has_placemark}")
            print(f"Has Document tag: {has_document}")
            print(f"Has Folder tag: {has_folder}")
        
        # Try parsing with minidom first to better understand the structure
        dom = minidom.parse(kml_path)
        
        # Print all element names to understand the structure
        element_names = set()
        for elem in dom.getElementsByTagName("*"):
            element_names.add(elem.tagName)
        
        print("Elements found in the file:")
        print(', '.join(element_names))
        
        # Count Placemarks
        placemarks = dom.getElementsByTagName("Placemark")
        print(f"Found {len(placemarks)} Placemarks using DOM parser")
        
        # Now parse with ElementTree for data extraction
        tree = ET.parse(kml_path)
        root = tree.getroot()
        
        # Try to determine the namespace
        root_tag = root.tag
        print(f"Root tag: {root_tag}")
        
        # Define possible namespaces
        namespaces = {
            'default': {},
            'kml': {'kml': 'http://www.opengis.net/kml/2.2'},
            'kml21': {'kml': 'http://earth.google.com/kml/2.1'},
            'kml22': {'kml': 'http://www.opengis.net/kml/2.2'},
            'atom': {'atom': 'http://www.w3.org/2005/Atom'}
        }
        
        # Open CSV file for writing
        with open(csv_path, 'w', newline='', encoding='utf-8') as csvfile:
            fieldnames = ['Stadium Name', 'Team', 'Address', 'City', 'State', 'Zip Code', 'Full Address']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            
            # Try each namespace to find placemarks
            placemarks = []
            used_ns = None
            
            for ns_name, ns in namespaces.items():
                # Try to find Placemarks at different levels of the hierarchy
                for xpath in [
                    './/Placemark',
                    './/kml:Placemark',
                    './/Document/Placemark',
                    './/kml:Document/kml:Placemark',
                    './/Folder/Placemark',
                    './/kml:Folder/kml:Placemark'
                ]:
                    try:
                        found = root.findall(xpath, ns)
                        if found:
                            placemarks = found
                            used_ns = ns
                            print(f"Found {len(placemarks)} Placemarks using XPath '{xpath}' with namespace {ns_name}")
                            break
                    except Exception as e:
                        pass  # Ignore errors for invalid XPaths
                
                if placemarks:
                    break
            
            if not placemarks:
                print("No Placemarks found in the KML file using any standard method.")
                
                # Last resort: try to find all elements that might be Placemarks
                print("Trying to manually traverse the XML structure...")
                
                def find_placemarks(element, path=""):
                    found = []
                    new_path = path + "/" + element.tag.split("}")[-1]
                    
                    # Check if this element looks like a Placemark
                    children_tags = [child.tag.split("}")[-1] for child in element]
                    if "name" in children_tags and ("address" in children_tags or "ExtendedData" in children_tags):
                        print(f"Found potential Placemark-like element at {new_path}")
                        found.append(element)
                    
                    # Recursively check children
                    for child in element:
                        found.extend(find_placemarks(child, new_path))
                    
                    return found
                
                placemarks = find_placemarks(root)
                print(f"Found {len(placemarks)} potential Placemark-like elements")
            
            if not placemarks:
                print("Could not find any Placemark elements in the file.")
                return False
            
            # Process each Placemark
            processed_count = 0
            for placemark in placemarks:
                stadium_data = {
                    'Stadium Name': '',
                    'Team': '',
                    'Address': '',
                    'City': '',
                    'State': '',
                    'Zip Code': '',
                    'Full Address': ''
                }
                
                # Debug info
                print(f"\nProcessing Placemark {processed_count + 1}:")
                
                # Try different ways to get the name
                for name_path in ['name', 'kml:name', './/name', './/kml:name']:
                    try:
                        name_elem = placemark.find(name_path, used_ns)
                        if name_elem is not None and name_elem.text:
                            stadium_data['Stadium Name'] = name_elem.text
                            print(f"Found name: {name_elem.text}")
                            break
                    except:
                        continue
                
                # Try different ways to get the address
                for addr_path in ['address', 'kml:address', './/address', './/kml:address']:
                    try:
                        addr_elem = placemark.find(addr_path, used_ns)
                        if addr_elem is not None and addr_elem.text:
                            stadium_data['Full Address'] = addr_elem.text
                            print(f"Found address: {addr_elem.text}")
                            break
                    except:
                        continue
                
                # Try to get ExtendedData
                extended_data = None
                for ed_path in ['ExtendedData', 'kml:ExtendedData', './/ExtendedData', './/kml:ExtendedData']:
                    try:
                        ed = placemark.find(ed_path, used_ns)
                        if ed is not None:
                            extended_data = ed
                            print("Found ExtendedData")
                            break
                    except:
                        continue
                
                if extended_data is not None:
                    # Try different ways to get Data elements
                    data_elements = []
                    for data_path in ['Data', 'kml:Data', './/Data', './/kml:Data']:
                        try:
                            elements = extended_data.findall(data_path, used_ns)
                            if elements:
                                data_elements = elements
                                print(f"Found {len(elements)} Data elements")
                                break
                        except:
                            continue
                    
                    # Process each Data element
                    for data in data_elements:
                        try:
                            data_name = data.get('name')
                            
                            # Try different ways to get the value
                            value_text = None
                            for value_path in ['value', 'kml:value', './/value', './/kml:value']:
                                try:
                                    value_elem = data.find(value_path, used_ns)
                                    if value_elem is not None and value_elem.text is not None:
                                        value_text = value_elem.text
                                        break
                                except:
                                    continue
                            
                            if data_name and value_text:
                                print(f"Data: {data_name} = {value_text}")
                                
                                if data_name == 'Team':
                                    stadium_data['Team'] = value_text
                                elif data_name == 'addresss' or data_name == 'address' or data_name == 'Address':
                                    stadium_data['Address'] = value_text
                                elif data_name == 'City':
                                    stadium_data['City'] = value_text
                                elif data_name == 'State':
                                    stadium_data['State'] = value_text.strip()
                                elif data_name == 'Zip Code' or data_name == 'Zip' or data_name == 'ZipCode':
                                    stadium_data['Zip Code'] = value_text
                        except Exception as e:
                            print(f"Error processing Data element: {e}")
                
                # If we found any data, write it to the CSV
                if any(stadium_data.values()):
                    writer.writerow(stadium_data)
                    processed_count += 1
                    print(f"Wrote data for {stadium_data['Stadium Name']}")
                else:
                    print("No data found for this Placemark")
            
            print(f"\nSuccessfully processed {processed_count} out of {len(placemarks)} Placemarks")
            print(f"Data written to {os.path.abspath(csv_path)}")
            
            if processed_count == 0:
                print("WARNING: No data was written to the CSV file!")
                return False
                
            return True
    
    except ET.ParseError as pe:
        print(f"Error parsing XML/KML file: {pe}")
        print("This might not be a valid KML file or it has syntax errors.")
        return False
    except Exception as e:
        print(f"Unexpected error processing KML file: {e}")
        import traceback
        traceback.print_exc()
        return False

def main():
    # Try different possible paths for the KML file
    possible_paths = [
        "merged/data/temp_unzipped/doc.kml",
        "doc.kml",
        "data/doc.kml",
        "temp_unzipped/doc.kml",
        # Add more potential paths if needed
    ]
    
    csv_file = "49ers_fan_chapters.csv"
    
    # Allow command line argument for the KML path
    if len(sys.argv) > 1:
        possible_paths.insert(0, sys.argv[1])
    
    success = False
    for path in possible_paths:
        print(f"Trying path: {path}")
        if os.path.exists(path):
            success = extract_kml_to_csv(path, csv_file)
            if success:
                break
    
    if not success:
        print("\nCould not successfully process any of the tried KML paths.")
        print("Please provide the correct path to the KML file as a command line argument:")
        print(f"python {sys.argv[0]} path/to/your/kml/file.kml")

if __name__ == "__main__":
    main()
# Out:
# Trying path: --f=/Users/alex.liss/Library/Jupyter/runtime/kernel-v3452aeb21f01dc22f1ba4a44eaf93aa20d3e82e83.json
# Trying path: merged/data/temp_unzipped/doc.kml
# Trying path: doc.kml
# Trying path: data/doc.kml
# Trying path: temp_unzipped/doc.kml
# Attempting to read KML file from: /Users/alex.liss/Documents/1_DS AI LIVE /NEW MERGED PROJECT/merged/data/temp_unzipped/doc.kml
# Analyzing KML file structure...
# File size: 1996505 bytes
# First 500 characters of file: <?xml version="1.0" encoding="UTF-8"?>
# <kml xmlns="http://www.opengis.net/kml/2.2">
#   <Document>
#     <name>49ers Fan Chapters</name>
#     <description/>
#     <Style id="icon-1698-BDBDBD-normal">
#       <IconStyle>
#         <scale>1</scale>
#         <Icon>
#           <href>images/icon-1.png</href>
#         </Icon>
#       </IconStyle>
#       <LabelStyle>
#         <scale>0</scale>
#       </LabelStyle>
#     </Style>
#     <Style id="icon-1698-BDBDBD-highlight">
#       <IconStyle>
#         <scale>1</scale>
#         <
# Has KML tag: True
# Has Placemark tags: True
# Has Document tag: True
# Has Folder tag: True
# Elements found in the file:
# Pair, description, Icon, StyleMap, address, href, ExtendedData, value, Data, LabelStyle, name, key, kml, hotSpot, Placemark, styleUrl, Style, scale, Folder, Document, IconStyle
# Found 797 Placemarks using DOM parser
# Root tag: {http://www.opengis.net/kml/2.2}kml
# Found 797 Placemarks using XPath './/kml:Placemark' with namespace kml
#
# Processing Placemark 1:
# Found name: State Farm Stadium
# Found address: 1 Cardinals Dr. Glendale  Arizona 85305
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Arizona Cardinals
# Data: addresss = 1 Cardinals Dr.
# Data: City = Glendale
# Data: State =  Arizona
# Data: Zip Code = 85305
# Wrote data for State Farm Stadium
#
# Processing Placemark 2:
# Found name: Mercedes-Benz Stadium
# Found address: 1 AMB Drive NW Atlanta  Georgia 30313
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Atlanta Falcons
# Data: addresss = 1 AMB Drive NW
# Data: City = Atlanta
# Data: State =  Georgia
# Data: Zip Code = 30313
# Wrote data for Mercedes-Benz Stadium
#
# Processing Placemark 3:
# Found name: M&T Bank Stadium
# Found address: Â 1101 Russell St Baltimore  Maryland 21230
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Baltimore Ravens
# Data: addresss = Â 1101 Russell St
# Data: City = Baltimore
# Data: State =  Maryland
# Data: Zip Code = 21230
# Wrote data for M&T Bank Stadium
#
# Processing Placemark 4:
# Found name: Highmark Stadium
# Found address: 1 Bills Dr Orchard Park  New York 14127
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Buffalo Bills
# Data: addresss = 1 Bills Dr
# Data: City = Orchard Park
# Data: State =  New York
# Data: Zip Code = 14127
# Wrote data for Highmark Stadium
#
# Processing Placemark 5:
# Found name: Bank of America Stadium
# Found address: 800 S Mint St Charlotte  North Carolina 28202
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Carolina Panthers
# Data: addresss = 800 S Mint St
# Data: City = Charlotte
# Data: State =  North Carolina
# Data: Zip Code = 28202
# Wrote data for Bank of America Stadium
#
# Processing Placemark 6:
# Found name: Soldier Field
# Found address: 1410 Museum Campus Dr Chicago  Illinois 60605
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Chicago Bears
# Data: addresss = 1410 Museum Campus Dr
# Data: City = Chicago
# Data: State =  Illinois
# Data: Zip Code = 60605
# Wrote data for Soldier Field
#
# Processing Placemark 7:
# Found name: Paul Brown Stadium
# Found address: 1 Paul Brown Stadium Cincinnati  Ohio 45202
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Cincinnati Bengals
# Data: addresss = 1 Paul Brown Stadium
# Data: City = Cincinnati
# Data: State =  Ohio
# Data: Zip Code = 45202
# Wrote data for Paul Brown Stadium
#
# Processing Placemark 8:
# Found name: FirstEnergy Stadium
# Found address: 100 Alfred Lerner Way Cleveland  Ohio 44114
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Cleveland Browns
# Data: addresss = 100 Alfred Lerner Way
# Data: City = Cleveland
# Data: State =  Ohio
# Data: Zip Code = 44114
# Wrote data for FirstEnergy Stadium
#
# Processing Placemark 9:
# Found name: AT&T Stadium
# Found address: 1 AT&T Way Arlington  Texas 76011
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Dallas Cowboys
# Data: addresss = 1 AT&T Way
# Data: City = Arlington
# Data: State =  Texas
# Data: Zip Code = 76011
# Wrote data for AT&T Stadium
#
# Processing Placemark 10:
# Found name: Empower Field at Mile High
# Found address: Â 1701 Bryant St Denver  Colorado 80204
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Denver Broncos
# Data: addresss = Â 1701 Bryant St
# Data: City = Denver
# Data: State =  Colorado
# Data: Zip Code = 80204
# Wrote data for Empower Field at Mile High
#
# Processing Placemark 11:
# Found name: Ford Field
# Found address: 2000 Brush St Detroit  Michigan 48226
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Detroit Lions
# Data: addresss = 2000 Brush St
# Data: City = Detroit
# Data: State =  Michigan
# Data: Zip Code = 48226
# Wrote data for Ford Field
#
# Processing Placemark 12:
# Found name: Lambeau Field
# Found address: 1265 Lombardi Ave Green Bay  Wisconsin 54304
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Green Bay Packers
# Data: addresss = 1265 Lombardi Ave
# Data: City = Green Bay
# Data: State =  Wisconsin
# Data: Zip Code = 54304
# Wrote data for Lambeau Field
#
# Processing Placemark 13:
# Found name: NRG Stadium
# Found address: NRG Pkwy Houston  Texas 77054
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Houston Texans
# Data: addresss = NRG Pkwy
# Data: City = Houston
# Data: State =  Texas
# Data: Zip Code = 77054
# Wrote data for NRG Stadium
#
# Processing Placemark 14:
# Found name: Lucas Oil Stadium
# Found address: 500 S Capitol Ave Indianapolis  Indiana 46225
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Indianapolis Colts
# Data: addresss = 500 S Capitol Ave
# Data: City = Indianapolis
# Data: State =  Indiana
# Data: Zip Code = 46225
# Wrote data for Lucas Oil Stadium
#
# Processing Placemark 15:
# Found name: EverBank Field
# Found address: 1 Everbank Field Dr Jacksonville  Florida 32202
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Jacksonville Jaguars
# Data: addresss = 1 Everbank Field Dr
# Data: City = Jacksonville
# Data: State =  Florida
# Data: Zip Code = 32202
# Wrote data for EverBank Field
#
# Processing Placemark 16:
# Found name: Arrowhead Stadium
# Found address: 1 Arrowhead Dr Kansas City  Missouri 64129
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Kansas City Chiefs
# Data: addresss = 1 Arrowhead Dr
# Data: City = Kansas City
# Data: State =  Missouri
# Data: Zip Code = 64129
# Wrote data for Arrowhead Stadium
#
# Processing Placemark 17:
# Found name: SoFi Stadium
# Found address: 1001 Stadium Dr Inglewood  California 90301
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Los Angeles Chargers & Los Angeles Rams
# Data: addresss = 1001 Stadium Dr
# Data: City = Inglewood
# Data: State =  California
# Data: Zip Code = 90301
# Wrote data for SoFi Stadium
#
# Processing Placemark 18:
# Found name: Hard Rock Stadium
# Found address: 347 Don Shula Dr Miami Gardens  Florida 33056
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Miami Dolphins
# Data: addresss = 347 Don Shula Dr
# Data: City = Miami Gardens
# Data: State =  Florida
# Data: Zip Code = 33056
# Wrote data for Hard Rock Stadium
#
# Processing Placemark 19:
# Found name: U.S. Bank Stadium
# Found address: 401 Chicago Avenue Minneapolis  Minnesota 55415
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Minnesota Vikings
# Data: addresss = 401 Chicago Avenue
# Data: City = Minneapolis
# Data: State =  Minnesota
# Data: Zip Code = 55415
# Wrote data for U.S. Bank Stadium
#
# Processing Placemark 20:
# Found name: Gillette Stadium
# Found address: 1 Patriot Pl Foxborough  Massachusetts 2035
# Found ExtendedData
# Found 5 Data elements
# Data: Team = New England Patriots
# Data: addresss = 1 Patriot Pl
# Data: City = Foxborough
# Data: State =  Massachusetts
# Data: Zip Code = 2035
# Wrote data for Gillette Stadium
#
# Processing Placemark 21:
# Found name: Caesars Superdome
# Found address: 1500 Sugar Bowl Dr New Orleans  Louisiana 70112
# Found ExtendedData
# Found 5 Data elements
# Data: Team = New Orleans Saints
# Data: addresss = 1500 Sugar Bowl Dr
# Data: City = New Orleans
# Data: State =  Louisiana
# Data: Zip Code = 70112
# Wrote data for Caesars Superdome
#
# Processing Placemark 22:
# Found name: MetLife Stadium
# Found address: 1 MetLife Stadium D East Rutherford  New Jersey 7073
# Found ExtendedData
# Found 5 Data elements
# Data: Team = New York Giants & New York Jets
# Data: addresss = 1 MetLife Stadium D
# Data: City = East Rutherford
# Data: State =  New Jersey
# Data: Zip Code = 7073
# Wrote data for MetLife Stadium
#
# Processing Placemark 23:
# Found name: Allegiant Stadium
# Found address: 3333 Al Davis Way Las Vegas Nevada 89118
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Las Vegas Raiders
# Data: addresss = 3333 Al Davis Way
# Data: City = Las Vegas
# Data: State = Nevada
# Data: Zip Code = 89118
# Wrote data for Allegiant Stadium
#
# Processing Placemark 24:
# Found name: Lincoln Financial Field
# Found address: 1 Lincoln Financial Field Way Philadelphia  Pennsylvania 19148
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Philadelphia Eagles
# Data: addresss = 1 Lincoln Financial Field Way
# Data: City = Philadelphia
# Data: State =  Pennsylvania
# Data: Zip Code = 19148
# Wrote data for Lincoln Financial Field
#
# Processing Placemark 25:
# Found name: Heinz Field
# Found address: 100 Art Rooney Ave Pittsburgh  Pennsylvania 15212
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Pittsburgh Steelers
# Data: addresss = 100 Art Rooney Ave
# Data: City = Pittsburgh
# Data: State =  Pennsylvania
# Data: Zip Code = 15212
# Wrote data for Heinz Field
#
# Processing Placemark 26:
# Found name: Levi's Stadium
# Found address: 4900 Marie P DeBartolo Way  Santa Clara  California 95054
# Found ExtendedData
# Found 5 Data elements
# Data: Team = San Francisco 49ers
# Data: addresss = 4900 Marie P DeBartolo Way
# Data: City = Santa Clara
# Data: State =  California
# Data: Zip Code = 95054
# Wrote data for Levi's Stadium
#
# Processing Placemark 27:
# Found name: Lumen Field
# Found address: 800 Occidental Ave Seattle  Washington 98134
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Seattle Seahawks
# Data: addresss = 800 Occidental Ave
# Data: City = Seattle
# Data: State =  Washington
# Data: Zip Code = 98134
# Wrote data for Lumen Field
#
# Processing Placemark 28:
# Found name: Raymond James Stadium
# Found address: 4201 N Dale Mabry Hwy Tampa  Florida 33607
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Tampa Bay Buccaneers
# Data: addresss = 4201 N Dale Mabry Hwy
# Data: City = Tampa
# Data: State =  Florida
# Data: Zip Code = 33607
# Wrote data for Raymond James Stadium
#
# Processing Placemark 29:
# Found name: Nissan Stadium
# Found address: 1 Titans Way Nashville  Tennessee 37213
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Tennessee Titans
# Data: addresss = 1 Titans Way
# Data: City = Nashville
# Data: State =  Tennessee
# Data: Zip Code = 37213
# Wrote data for Nissan Stadium
#
# Processing Placemark 30:
# Found name: FedExField
# Found address: 1600 Fedex Way Landover  Maryland 20785
# Found ExtendedData
# Found 5 Data elements
# Data: Team = Washington Comanders
# Data: addresss = 1600 Fedex Way
# Data: City = Landover
# Data: State =  Maryland
# Data: Zip Code = 20785
# Wrote data for FedExField
#
# Processing Placemark 31:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 4492612712
# Data: ﻿Fan Chapter Name = 49ers Aguascalientes
# Data: President First Name = Cesar
# Data: President Last Name = Romo
# Data: Email Address = ninersaguascalientes@gmail.com
# Data: City = Aguascalientes
# Data: Country = Mexico
# Data: Venue = Vikingo Bar
# Data: Venue Location = Av de la Convención de 1914 Sur 312-A, Las Américas, 20230 Aguascalientes, Ags., Mexico
# Data: Total Fans = 174.0
# Data: Facebook = https://www.facebook.com/share/1Wa7TPzBMX/
# Wrote data for
#
# Processing Placemark 32:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (46) 1219 7801
# Data: ﻿Fan Chapter Name = Bajio Faithful
# Data: President First Name = Hector
# Data: President Last Name = Camarena
# Data: Email Address = hectorcamarena@hotmail.com
# Data: City = Celaya, GTO
# Data: Country = Mexico
# Data: Venue = California Prime Rib Restaurant
# Data: Venue Location = Av. Constituyentes 1000 A, 3 Guerras, 38080 Celaya, Gto., Mexico
# Data: Total Fans = 20.0
# Wrote data for
#
# Processing Placemark 33:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (96) 1654-1513
# Data: ﻿Fan Chapter Name = Niner Empire Chiapas
# Data: President First Name = Aroshi
# Data: President Last Name = Narvaez
# Data: Email Address = ninerempirechiapas@hotmail.com
# Data: City = Chiapas
# Data: Country = Mexico
# Data: Venue = Alitas Tuxtla
# Data: Venue Location = Blvd. Belisario Dominguez 1861 Loc K1 Tuxtl Fracc, Bugambilias, 29060 Tuxtla Gutiérrez, Chis., Mexico
# Data: Total Fans = 250.0
# Data: Facebook = Niner Empire Chiapas
# Data: Instagram = https://www.instagram.com/49erschiapas/?hl=en
# Data: X (Twitter) = Niner Empire Chiapas
# Wrote data for
#
# Processing Placemark 34:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (61) 4404-1411
# Data: ﻿Fan Chapter Name = 49ers Faithful Chihuahua Oficial
# Data: President First Name = Jorge
# Data: President Last Name = Otamendi
# Data: Email Address = chihuahua49ersfaithful@gmail.com
# Data: City = Chihuahua
# Data: Country = Mexico
# Data: Venue = El Coliseo Karaoke Sports Bar
# Data: Venue Location = C. Jose Maria Morelos 111, Zona Centro, 31000 Chihuahua, Chih., Mexico
# Data: Total Fans = 300.0
# Data: Facebook = https://www.facebook.com/share/g/14tnsAwWFc/
# Data: Instagram = https://www.instagram.com/49ersfaithfulchihuahua?igsh=bHE5ZWd6eTUxOWl3
# Data: TikTok = https://www.tiktok.com/@49ers.faithful.ch?_t=8rv1vcLFfBI&_r=1
# Wrote data for
#
# Processing Placemark 35:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (61) 41901197
# Data: ﻿Fan Chapter Name = Gold Rush Chihuahua Spartans
# Data: President First Name = Juan
# Data: President Last Name = García
# Data: Email Address = juga49er@gmail.com
# Data: City = Chihuahua
# Data: Country = Mexico
# Data: Venue = 34 Billiards & Drinks
# Data: Venue Location = Av. Tecnológico 4903, Las Granjas 31100
# Data: Total Fans = 976.0
# Data: Facebook = https://www.facebook.com/groups/170430893136916/
# Wrote data for
#
# Processing Placemark 36:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (55) 6477-1279
# Data: ﻿Fan Chapter Name = Club 49ers Mexico
# Data: President First Name = German
# Data: President Last Name = Rodriguez
# Data: Email Address = club49ersmexico@hotmail.com
# Data: City = Ciudad de Mexico, Mexico
# Data: Country = Mexico
# Data: Venue = Bar 49
# Data: Venue Location = 16 Septiembre #27 Colonia Centro Historico Ciudad de Mexico
# Data: Total Fans = 800.0
# Data: Instagram = club49ersmexico
# Data: X (Twitter) = club49ersmexico
# Data: TikTok = Club49ersmexicooficial
# Wrote data for
#
# Processing Placemark 37:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (55) 6904-5174
# Data: ﻿Fan Chapter Name = Club 49ers Durango Oficial
# Data: President First Name = Victor
# Data: President Last Name = Arballo
# Data: Email Address = Club49ersdurango@gmail.com
# Data: City = Durango
# Data: Country = Mexico
# Data: Venue = Restaurante Buffalucas Constitución
# Data: Venue Location = C. Constitución 107B, Zona Centro, 34000 Durango, Dgo., Mexico
# Data: Total Fans = 170.0
# Data: Facebook = https://www.facebook.com/share/1TaDBVZmx2/?mibextid=LQQJ4d
# Data: Instagram = https://www.instagram.com/49ers_dgo?igsh=ams1dHdibXZmN28w
# Wrote data for
#
# Processing Placemark 38:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (55) 707169
# Data: ﻿Fan Chapter Name = Niner Empire Edo Mex
# Data: President First Name = Alberto
# Data: President Last Name = Velasco
# Data: Email Address = ninerempireedomex@hotmail.com
# Data: City = Estado de Mexico
# Data: Country = Mexico
# Data: Venue = Beer Garden Satélite
# Data: Venue Location = Cto. Circunvalación Ote. 10-L-4, Cd. Satélite, 53100 Naucalpan de Juárez, Méx., Mexico
# Data: Total Fans = 250.0
# Data: Instagram = https://www.instagram.com/ninerempireedomex/
# Data: X (Twitter) = https://x.com/ninerempedomex
# Wrote data for
#
# Processing Placemark 39:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (33) 2225-4392
# Data: ﻿Fan Chapter Name = Club 49ers Jalisco
# Data: President First Name = Marcela
# Data: President Last Name = Medina
# Data: Email Address = 49ersjalisco@gmail.com
# Data: City = Guadalajara, Jalisco
# Data: Country = Mexico
# Data: Venue = Restaurante Modo Avión Zapopan
# Data: Venue Location = Calzada Nte 14, Granja, 45010 Zapopan, Jal., Mexico
# Data: Total Fans = 40.0
# Data: Instagram = club49ersjalisco
# Data: X (Twitter) = Club 49ers Jalisco
# Wrote data for
#
# Processing Placemark 40:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (33) 1046 3607
# Data: ﻿Fan Chapter Name = Niner Empire Jalisco
# Data: President First Name = Alonso
# Data: President Last Name = Partida
# Data: Email Address = ninerempirejal49@gmail.com
# Data: City = Guadalajara, Jalisco
# Data: Country = Mexico
# Data: Venue = SkyGames Sports Bar
# Data: Venue Location = Av. Vallarta 874 entre Camarena y, C. Escorza, Centro, 44100 Guadalajara, Jal., Mexico
# Data: Total Fans = 200.0
# Data: Instagram = niner_empire_jalisco
# Data: X (Twitter) = NinerEmpireJal
# Data: TikTok = ninerempirejal
# Wrote data for
#
# Processing Placemark 41:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (65) 6228-3719
# Data: ﻿Fan Chapter Name = Niner Empire Juarez Oficial
# Data: President First Name = Hugo
# Data: President Last Name = Montero
# Data: Email Address = JuarezFaithful@outlook.com
# Data: City = Juarez
# Data: Country = Mexico
# Data: Venue = Sport Bar Silver Fox
# Data: Venue Location = Av. Paseo Triunfo de la República 430, Las Fuentes, 32530 Juárez, Chih., Mexico
# Data: Total Fans = 300.0
# Wrote data for
#
# Processing Placemark 42:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (99) 9172-2810
# Data: ﻿Fan Chapter Name = 49ers Merida Oficial
# Data: President First Name = Liliana
# Data: President Last Name = Vargas
# Data: Email Address = contacto@49ersmerida.mx
# Data: City = Merida
# Data: Country = Mexico
# Data: Venue = Taproom Mastache
# Data: Venue Location = Av. Cámara de Comercio 263, San Ramón Nte, 97117 Mérida, Yuc., Mexico
# Data: Total Fans = 290.0
# Wrote data for
#
# Processing Placemark 43:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (686) 243 7235
# Data: ﻿Fan Chapter Name = Niner Empire Mexicali
# Data: President First Name = Gabriel
# Data: President Last Name = Carbajal
# Data: Email Address = ninerempiremxl@outlook.com
# Data: City = Mexicali
# Data: Country = Mexico
# Data: Venue = La Gambeta Terraza Sports Bar
# Data: Venue Location = Calz. Cuauhtémoc 328, Aviación, 21230 Mexicali, B.C., Mexico
# Data: Total Fans = 45.0
# Wrote data for
#
# Processing Placemark 44:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (81) 1500-4400
# Data: ﻿Fan Chapter Name = 49ers Monterrey Oficial
# Data: President First Name = Luis
# Data: President Last Name = González
# Data: Email Address = 49ersmonterrey@gmail.com
# Data: City = Monterrey
# Data: Country = Mexico
# Data: Venue = Buffalo Wild Wings Insurgentes
# Data: Venue Location = Av Insurgentes 3961, Sin Nombre de Col 31, 64620 Monterrey, N.L., Mexico
# Data: Total Fans = 1200.0
# Wrote data for
#
# Processing Placemark 45:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (22) 21914254
# Data: ﻿Fan Chapter Name = Club 49ers Puebla
# Data: President First Name = Elias
# Data: President Last Name = Mendez
# Data: Email Address = club49erspuebla@hotmail.com
# Data: City = Puebla
# Data: Country = Mexico
# Data: Venue = Bar John Barrigón
# Data: Venue Location = Av. Juárez 2925, La Paz, 72160 Heroica Puebla de Zaragoza, Pue., Mexico
# Wrote data for
#
# Processing Placemark 46:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (84) 4130-0064
# Data: ﻿Fan Chapter Name = Niners Empire Saltillo
# Data: President First Name = Carlos
# Data: President Last Name = Carrizales
# Data: Email Address = Ninerssaltillo21@gmail.com
# Data: City = Saltillo
# Data: Country = Mexico
# Data: Venue = Cervecería La Huérfana
# Data: Venue Location = Blvd. Venustiano Carranza 7046-Int 9, Los Rodríguez, 25200 Saltillo, Coah., Mexico
# Wrote data for
#
# Processing Placemark 47:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (44) 4257-3609
# Data: ﻿Fan Chapter Name = San Luis Potosi Oficial
# Data: President First Name = Jose
# Data: President Last Name = Robledo
# Data: Email Address = club49erssanluispotosi@hotmail.com
# Data: City = San Luis Potosi
# Data: Country = Mexico
# Data: Venue = Bar VIC
# Data: Venue Location = Av Nereo Rodríguez Barragán 1399, Fuentes del Bosque, 78220 San Luis Potosí, S.L.P., Mexico
# Wrote data for
#
# Processing Placemark 48:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (66) 4220-6991
# Data: ﻿Fan Chapter Name = 49ers Tijuana Fans Oficial
# Data: President First Name = Anthony
# Data: President Last Name = Daniel
# Data: Email Address = ant49ers14@gmail.com
# Data: City = Tijuana
# Data: Country = Mexico
# Data: Venue = Titan Sports Bar
# Data: Venue Location = J. Gorostiza 1209, Zona Urbana Rio Tijuana, 22320 Tijuana, B.C., Mexico
# Data: Total Fans = 460.0
# Data: Facebook = https://www.facebook.com/groups/49erstijuanafans/?ref=share&mibextid=NSMWBT
# Data: Instagram = https://www.instagram.com/49erstijuanafansoficial/?igshid=OGQ5ZDc2ODk2ZA%3D%3D&fbclid=IwZXh0bgNhZW0CMTEAAR0SXTcgDss1aAUjjzK6Ge0Uhx9JkNszzeQgTRq94F_5Zzat-arK9kXEqWk_aem_sKUysPZe1NpmFRPlJppOYw&sfnsn=scwspwa
# Data: X (Twitter) = -
# Data: TikTok = -
# Data: WhatsApp = -
# Data: YouTube = -
# Wrote data for
#
# Processing Placemark 49:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (72) 2498-5443
# Data: ﻿Fan Chapter Name = 49ers Club Toluca Oficial
# Data: President First Name = Fernando
# Data: President Last Name = Salazar
# Data: Email Address = ninersdealtura@gmail.com
# Data: City = Toluca
# Data: Country = Mexico
# Data: Venue = Revel Wings Carranza
# Data: Venue Location = Calle Gral. Venustiano Carranza 20 Pte. 905, Residencial Colón y Col Ciprés, 50120 Toluca de Lerdo, Méx., Mexico
# Wrote data for
#
# Processing Placemark 50:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 52 (228) 159-8578
# Data: ﻿Fan Chapter Name = Cluib de Fans 49ers Veracruz
# Data: President First Name = Luis
# Data: President Last Name = Mata
# Data: Email Address = los49ersdexalapa@gmail.com
# Data: City = Veracruz
# Data: Country = Mexico
# Data: Venue = Wings Army del Urban Center
# Data: Venue Location = C. Lázaro Cárdenas 102, Rafael Lucio, 91110 Xalapa-Enríquez, Ver., Mexico
# Wrote data for
#
# Processing Placemark 51:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6646124565
# Data: ﻿Fan Chapter Name = 49ersFanZone.net
# Data: President First Name = Clemens
# Data: President Last Name = Kaposi
# Data: Email Address = webmaster@49ersfanzone.net
# Data: City = Bad Vigaun
# Data: Country = Austria
# Data: Venue Location = Neuwirtsweg 315
# Data: Total Fans = 183.0
# Wrote data for
#
# Processing Placemark 52:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 33 (0)6 365 269 84
# Data: ﻿Fan Chapter Name = The Niner Empire France
# Data: President First Name = Gilles
# Data: President Last Name = Schlienger
# Data: Email Address = gilles.schlienger@orange.fr
# Data: City = Nousseviller Saint Nabor
# Data: Country = France
# Data: Venue = 4 voie romaine
# Data: Venue Location = 4 voie romaine
# Data: Total Fans = 250.0
# Data: Facebook = https://www.facebook.com/groups/295995597696338
# Wrote data for
#
# Processing Placemark 53:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1704753958
# Data: ﻿Fan Chapter Name = Niner Empire Germany-Bavaria Chapter
# Data: President First Name = Mike
# Data: President Last Name = Beckmann
# Data: Email Address = beckmannm55@gmail.com
# Data: City = Ismaning
# Data: Country = Germany
# Data: Venue = 49er's Sports & Partybar
# Data: Venue Location = Muenchener Strasse 79
# Data: Total Fans = 35.0
# Wrote data for
#
# Processing Placemark 54:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1735106462
# Data: ﻿Fan Chapter Name = 4T9 Mob Germany Family
# Data: President First Name = Chris
# Data: President Last Name = Grawert
# Data: Email Address = chrisgrawert@web.de
# Data: City = Hamburg
# Data: Country = Germany
# Data: Venue = Jolly Roger
# Data: Venue Location = Budapester Str. 44
# Data: Total Fans = 6.0
# Data: Facebook = https://www.facebook.com/4T9MOBGermany
# Wrote data for
#
# Processing Placemark 55:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 49 15758229310
# Data: ﻿Fan Chapter Name = 49 Niner Empire
# Data: President First Name = Andra
# Data: President Last Name = Theunert
# Data: Email Address = jan.andre77@web.de
# Data: City = Cologne State: NRW
# Data: Country = Germany
# Data: Venue = Joe Camps Sports Bar
# Data: Venue Location = Joe Champs
# Data: Total Fans = 104.0
# Wrote data for
#
# Processing Placemark 56:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1795908826
# Data: ﻿Fan Chapter Name = The Niner Empire Germany Berlin Chapter
# Data: President First Name = Jermaine
# Data: President Last Name = Benthin
# Data: Email Address = jermaine.benthin@icloud.com
# Data: City = Berlin
# Data: Country = Germany
# Data: Venue = Sportsbar Tor133
# Data: Venue Location = Torstrasse 133
# Data: Total Fans = 17.0
# Wrote data for
#
# Processing Placemark 57:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1607512643
# Data: President First Name = Heltewig
# Data: President Last Name = Thorsten
# Data: Email Address = t.heltewig@t-online.de
# Data: City = BornhÃ¶ved
# Data: Country = Germany
# Data: Venue = Comeback
# Data: Venue Location = MÃ¼hlenstraÃŸe 11
# Data: Total Fans = 20.0
# Wrote data for
#
# Processing Placemark 58:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1738803983
# Data: ﻿Fan Chapter Name = 49ers Fans Bavaria
# Data: President First Name = Thomas
# Data: President Last Name = Igerl
# Data: Email Address = thomas.igerl@gmx.de
# Data: City = Ampfing
# Data: Country = Germany
# Data: Venue = Holzheim 1a/Ampfing
# Data: Venue Location = Holzheim 1a
# Data: Total Fans = 30.0
# Data: Facebook = https://www.facebook.com/49ersfansbavaria
# Wrote data for
#
# Processing Placemark 59:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1234567899
# Data: Website = http://germany.theninerempire.com/
# Data: ﻿Fan Chapter Name = The Niner Empire Germany - North Rhine-Westphalia Chapter
# Data: President First Name = Timo
# Data: President Last Name = Allhoff
# Data: Email Address = timo.allhoff@web.de
# Data: City = Duesseldorf
# Data: Country = Germany
# Data: Venue = Knoten
# Data: Venue Location = Kurze Strasse 1A
# Data: Total Fans = 62.0
# Wrote data for
#
# Processing Placemark 60:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1708859408
# Data: ﻿Fan Chapter Name = Niner Empire Germany-NRW Chapter
# Data: President First Name = Hermann
# Data: President Last Name = van
# Data: Email Address = vanbebberhermann@yahoo.com
# Data: City = Cologne
# Data: Country = Germany
# Data: Venue = Joe Champs Sportsbar Cologne
# Data: Venue Location = Hohenzollernring 1 -3
# Data: Total Fans = 27.0
# Wrote data for
#
# Processing Placemark 61:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 3.53E+11
# Data: ﻿Fan Chapter Name = The Irish Faithful
# Data: President First Name = Colly
# Data: President Last Name = Mc
# Data: Email Address = 49ersire@gmail.com
# Data: City = Dublin 13
# Data: Country = Ireland
# Data: Venue = Busker On The Ball
# Data: Venue Location = 13 - 17 Fleet Street
# Data: Total Fans = 59.0
# Data: X (Twitter) = https://twitter.com/49ersIre
# Wrote data for
#
# Processing Placemark 62:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 0039 3282181898
# Data: ﻿Fan Chapter Name = 49ers Italian Fan Club
# Data: President First Name = Enzo
# Data: President Last Name = Marrocchino
# Data: Email Address = 49ers.italian@gmail.com + marrocchino.enxo@gmail.com
# Data: City = Fiorano Modenese
# Data: Country = Italy
# Data: Venue = The Beer Corner
# Data: Venue Location = Via Roma, 2/A
# Data: Total Fans = 50.0
# Data: Facebook = https://www.facebook.com/groups/49ersItalianFanClub
# Wrote data for
#
# Processing Placemark 63:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 649058694
# Data: Website = https://laminapodcast.wixsite.com/lamina
# Data: ﻿Fan Chapter Name = Mineros Spanish Faithful
# Data: President First Name = Luis
# Data: President Last Name = Miguel
# Data: Email Address = laminapodcast@gmail.com + luismiperez17@gmail.com
# Data: City = Madrid
# Data: Country = Spain
# Data: Venue = Penalti Lounge Bar
# Data: Venue Location = Avenida Reina 15
# Data: Total Fans = 15.0
# Wrote data for
#
# Processing Placemark 64:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6507841235
# Data: Website = http://www.sportssf.com.br
# Data: ﻿Fan Chapter Name = Equipe Sports SF
# Data: President First Name = Alessandro
# Data: President Last Name = Marques
# Data: Email Address = alessandro.quiterio@sportssf.com.br
# Data: City = Sao Paulo
# Data: Country = Brazil
# Data: Venue = Website, Podcast, Facebook Page, Twitter
# Data: Venue Location = Rua Hitoshi Ishibashi, 11 B
# Data: Total Fans = 14.0
# Wrote data for
#
# Processing Placemark 65:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1197444761
# Data: Website = http://www.49ersbrasil.com.br
# Data: ﻿Fan Chapter Name = 49ers Brasil
# Data: President First Name = Fabio
# Data: President Last Name = Moraes
# Data: Email Address = fbo_krun@live.co.uk
# Data: City = Campo Limpo, Sao Paulo
# Data: Country = Brazil
# Data: Venue = Bars and Restaurants in SÃ£o Paulo - SP
# Data: Total Fans = 870.0
# Wrote data for
#
# Processing Placemark 66:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 5511992650
# Data: ﻿Fan Chapter Name = San Francisco 49ers Brasil
# Data: President First Name = Otavio
# Data: President Last Name = Alban
# Data: Email Address = otavio.alban@gmail.com
# Data: City = Sao Bernardo do Campo, Sao Paulo
# Data: Country = Brazil
# Data: Venue = Multiple locations around south and southeast states of Brazil
# Data: Total Fans = 104.0
# Data: Facebook = https://www.facebook.com/groups/49ninersbrasil/
# Wrote data for
#
# Processing Placemark 67:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6046266697
# Data: Website = http://www.theninerempire.com
# Data: ﻿Fan Chapter Name = Niner Empire --Vanouver,BC Chapter
# Data: President First Name = Hector
# Data: President Last Name = Alvarado/Neil
# Data: Email Address = hector_alvarado21@hotmail.com
# Data: City = Vancouver, BC
# Data: Country = Canada
# Data: Venue = The Sharks Club--Langley, BC
# Data: Venue Location = 20169 88 Avenue
# Data: Total Fans = 31.0
# Wrote data for
#
# Processing Placemark 68:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 4167796921
# Data: ﻿Fan Chapter Name = True North Niners
# Data: President First Name = Shawn
# Data: President Last Name = Vromman
# Data: Email Address = truenorthniners@gmail.com
# Data: City = Bolton, Ontario
# Data: Country = Canada
# Data: Venue = Maguire's Pub
# Data: Venue Location = 284 Queen st E
# Data: Total Fans = 25.0
# Wrote data for
#
# Processing Placemark 69:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 507 66737171
# Data: ﻿Fan Chapter Name = Faithful Panama
# Data: President First Name = Ricardo
# Data: President Last Name = Vallarino
# Data: Email Address = ricardovallarino@hotmail.com
# Data: Country = Panama
# Data: Venue = 5inco Panama
# Data: Venue Location = 8530 NW 72ND ST
# Data: Total Fans = 249.0
# No data found for this Placemark
#
# Processing Placemark 69:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6493015128
# Data: ﻿Fan Chapter Name = Niner Empire New Zealand
# Data: President First Name = Karam
# Data: President Last Name = Chand
# Data: Email Address = karam.chand@asb.co.nz
# Data: City = Auckland
# Data: Country = New Zealand
# Data: Venue = The Kingslander
# Data: Venue Location = 470 New North Road
# Data: Total Fans = 15.0
# Data: Facebook = https://www.facebook.com/#!/groups/212472585456813/
# Wrote data for
#
# Processing Placemark 70:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6768804977
# Data: ﻿Fan Chapter Name = 49er Fans-Tonga
# Data: President First Name = Nusi
# Data: President Last Name = Taumoepeau
# Data: Email Address = nusi.taumoepeau@gmail.com
# Data: City = Nuku'alofa
# Data: Country = Tonga
# Data: Venue = Tali'eva Bar
# Data: Venue Location = 14 Taufa'ahau Rd
# Data: Total Fans = 8.0
# Wrote data for
#
# Processing Placemark 71:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 7857047023
# Data: ﻿Fan Chapter Name = 49ers Faithful UK
# Data: President First Name = Mike
# Data: President Last Name = Palmer
# Data: Email Address = 49erfaithfuluk@gmail.com
# Data: City = Greater Manchester
# Data: Country = United Kingdom
# Data: Venue = the green
# Data: Venue Location = Ducie street Manchester Greater Manchester Lancashire m1 United Kingdom
# Data: Total Fans = 100.0
# Wrote data for
#
# Processing Placemark 72:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 7506116581
# Data: Website = www.49erfaithfuluk.co.uk
# Data: ﻿Fan Chapter Name = 49er Faithful UK
# Data: President First Name = Lee
# Data: President Last Name = Gowland
# Data: Email Address = contact@49erfaithfuluk.co.uk
# Data: City = Newcastle
# Data: Country = United Kingdom
# Data: Venue = Grosvenor Casino
# Data: Venue Location = 100 St James' Blvd Newcastle Tyne & Wear CA 95054 United Kingdom
# Data: Total Fans = 3000.0
# Wrote data for
#
# Processing Placemark 73:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 8774734977
# Data: ﻿Fan Chapter Name = 49ers of United Kingdom
# Data: President First Name = Nauman
# Data: President Last Name = Malik
# Data: Email Address = naumalik@gmail.com
# Data: City = London
# Data: Country = United Kingdom
# Data: Venue = The Sports Cafe
# Data: Venue Location = 80 Haymarket London SW1Y 4TE United Kingdom
# Data: Total Fans = 8.0
# Wrote data for
#
# Processing Placemark 74:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 1616553629
# Data: ﻿Fan Chapter Name = Niner Empire UK
# Data: President First Name = Mike
# Data: President Last Name = Palmer
# Data: Email Address = ninerempireuk@gmail.com
# Data: City = Manchester
# Data: Country = United Kingdom
# Data: Venue = The Green
# Data: Venue Location = Bridge House 26 Ducie Street, Manchester, Manchester M1 2dq United Kingdom
# Data: Total Fans = 30.0
# Wrote data for
#
# Processing Placemark 75:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6264841085
# Data: ﻿Fan Chapter Name = San Francisco 49er Fans of Charleston, SC
# Data: President First Name = Kurtis
# Data: President Last Name = Johnson
# Data: Email Address = kajohnson854@yahoo.com
# Data: City = Charleston
# Data: State = SC
# Data: Country = United States
# Data: Venue = Recovery Room Tavern
# Data: Venue Location = 685 King St
# Data: Total Fans = 12.0
# Data: Facebook = https://www.facebook.com/profile.php?id=100095655455065
# Wrote data for
#
# Processing Placemark 76:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 5309536097
# Data: ﻿Fan Chapter Name = 530 Empire
# Data: President First Name = Oscar
# Data: President Last Name = Mendoza
# Data: Email Address = ninermendoza@gmail.com
# Data: City = Chico
# Data: State = Ca
# Data: Country = United States
# Data: Venue = Nash's
# Data: Venue Location = 1717 Esplanade
# Data: Total Fans = 45.0
# Data: Instagram = https://www.instagram.com/530empire?igsh=OGQ5ZDc2ODk2ZA%3D%3D&utm_source=qr
# Wrote data for
#
# Processing Placemark 77:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = (720) 345-2580
# Data: ﻿Fan Chapter Name = 303 Denver Chapter Niner Empire
# Data: President First Name = Andy
# Data: President Last Name = Martinez
# Data: Email Address = 303denverchapter@gmail.com
# Data: City = Aurora
# Data: State = CO
# Data: Country = United States
# Data: Venue = Moes Bbq
# Data: Venue Location = 2727 s Parker rd
# Data: Total Fans = 30.0
# Wrote data for
#
# Processing Placemark 78:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 3238332262
# Data: ﻿Fan Chapter Name = 40NINERS L.A. CHAPTER
# Data: President First Name = JOSE
# Data: President Last Name = DIAZ
# Data: Email Address = 40ninerslachapter@att.net
# Data: City = bell
# Data: State = ca
# Data: Country = United States
# Data: Venue = KRAZY WINGS SPORTS & GRILL
# Data: Venue Location = 7016 ATLANTIC AVE
# Data: Total Fans = 25.0
# Wrote data for
#
# Processing Placemark 79:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = (434) 441-1187
# Data: ﻿Fan Chapter Name = 434 Virginia Niner Empire
# Data: President First Name = Thomas
# Data: President Last Name = Hunt
# Data: Email Address = 434vaninerempire@gmail.com
# Data: City = Danville
# Data: State = VA
# Data: Country = United States
# Data: Venue = Kickbacks Jacks
# Data: Venue Location = 140 Crown Dr
# Data: Total Fans = 20.0
# Wrote data for
#
# Processing Placemark 80:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = (925) 457-6175
# Data: ﻿Fan Chapter Name = 480 Gilbert Niner Empire LLC
# Data: President First Name = Betty
# Data: President Last Name = OLIVARES
# Data: Email Address = 480ninerempire@gmail.com
# Data: City = Gilbert
# Data: State = AZ
# Data: Country = United States
# Data: Venue = The Brass Tap
# Data: Venue Location = 313 n Gilbert rd
# Data: Total Fans = 100.0
# Wrote data for
#
# Processing Placemark 81:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 8126048419
# Data: ﻿Fan Chapter Name = Midwest Empire
# Data: President First Name = Travis
# Data: President Last Name = Bonnell
# Data: Email Address = 49er4life05@gmail.com
# Data: City = Evansville
# Data: State = IN
# Data: Country = United States
# Data: Venue = Hooters Evansville
# Data: Venue Location = 2112 Bremmerton Dr
# Data: Total Fans = 6.0
# Data: Facebook = https://www.facebook.com/share/5KGRDSPtyHgFYRSP/?mibextid=K35XfP
# Wrote data for
#
# Processing Placemark 82:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 7075921442
# Data: ﻿Fan Chapter Name = 49er Booster Club of Vacaville
# Data: President First Name = Josh
# Data: President Last Name = Ojeda
# Data: Email Address = 49erboostervacaville@gmail.com
# Data: City = Vacaville
# Data: State = CA
# Data: Country = United States
# Data: Venue = Blondies Bar and Grill
# Data: Venue Location = 555 Main Street
# Data: Total Fans = 75.0
# Wrote data for
#
# Processing Placemark 83:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 7602655202
# Data: ﻿Fan Chapter Name = 49er Empire High Desert
# Data: President First Name = TJ
# Data: President Last Name = Hilliard
# Data: Email Address = 49erempirehighdesert@gmail.com
# Data: City = Hesperia
# Data: State = California
# Data: Country = United States
# Data: Venue = Whiskey Barrel
# Data: Venue Location = 12055 Mariposa Rd.
# Data: Total Fans = 89.0
# Data: Facebook = https://www.facebook.com/groups/49erEmpireHighDesertChapter/
# Wrote data for
#
# Processing Placemark 84:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 5308239740
# Data: ﻿Fan Chapter Name = Cool 49er Booster Club
# Data: President First Name = Paul
# Data: President Last Name = Jones
# Data: Email Address = 49erpaul@comcast.net
# Data: City = Cool
# Data: State = CA
# Data: Country = United States
# Data: Venue = The Cool Beerworks
# Data: Venue Location = 5020 Ellinghouse Dr Suite H
# Data: Total Fans = 59.0
# Wrote data for
#
# Processing Placemark 85:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 8183269651
# Data: ﻿Fan Chapter Name = 49ersBeachCitiesSoCal
# Data: President First Name = Rick
# Data: President Last Name = Mitchell
# Data: Email Address = 49ersbeachcitiessocal@gmail.com
# Data: City = Hermosa Beach
# Data: State = CA
# Data: Country = United States
# Data: Venue = American Junkie Sky Light Bar
# Data: Venue Location = American Junkie
# Data: Total Fans = 100.0
# Wrote data for
#
# Processing Placemark 86:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 7202278251
# Data: ﻿Fan Chapter Name = 49ers Denver Empire
# Data: President First Name = Miguel
# Data: President Last Name = Alaniz
# Data: Email Address = 49ersDenverEmpire@gmail.com
# Data: City = Aurora
# Data: State = Co
# Data: Country = United States
# Data: Venue = Moe's Original BBQ Aurora
# Data: Venue Location = 2727 S Parker Rd
# Data: Total Fans = 30.0
# Wrote data for
#
# Processing Placemark 87:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 3605679487
# Data: ﻿Fan Chapter Name = 49ers Forever Faithfuls
# Data: President First Name = Wayne
# Data: President Last Name = Yelloweyes-Ripoyla
# Data: Email Address = 49ersforeverfaithfuls@gmail.com
# Data: City = Vancouver
# Data: State = Wa
# Data: Country = United States
# Data: Venue = Hooligan's sports bar and grill
# Data: Venue Location = 8220 NE Vancouver Plaza Dr, Vancouver, WA 98662
# Data: Total Fans = 10.0
# Wrote data for
#
# Processing Placemark 88:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 9566600391
# Data: ﻿Fan Chapter Name = South Texas 49ers Chapter
# Data: President First Name = Patty
# Data: President Last Name = Torres
# Data: Email Address = 49erslakersfaithful@gmail.com
# Data: City = Harlingen
# Data: State = TX
# Data: Country = United States
# Data: Venue = Wing barn
# Data: Venue Location = 412 sunny side ln
# Data: Total Fans = 350.0
# Data: Facebook = https://www.facebook.com/groups/2815298045413319/?ref=share
# Wrote data for
#
# Processing Placemark 89:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 3109547822
# Data: ﻿Fan Chapter Name = 49ers Los Angeles
# Data: President First Name = Jeff
# Data: President Last Name = Cheung
# Data: Email Address = 49ersLosAngeles@gmail.com
# Data: City = Hollywood
# Data: State = CA
# Data: Country = United States
# Data: Venue = Dave & Buster's Hollywood
# Data: Venue Location = 6801 Hollywood Blvd.
# Data: Total Fans = 27.0
# Wrote data for
#
# Processing Placemark 90:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 3234765148
# Data: ﻿Fan Chapter Name = 49ers United Of Frisco TX
# Data: President First Name = Frank
# Data: President Last Name = Murillo
# Data: Email Address = 49ersunitedoffriscotx@gmail.com
# Data: City = Frisco
# Data: State = TX
# Data: Country = United States
# Data: Venue = The Frisco Bar and Grill
# Data: Venue Location = 6750 Gaylord Pkwy
# Data: Total Fans = 1020.0
# Data: Facebook = https://www.facebook.com/groups/49ersunitedoffriscotx/?ref=share&mibextid=hubsqH
# Wrote data for
#
# Processing Placemark 91:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6193151122
# Data: ﻿Fan Chapter Name = 619ers San Diego Niner Empire
# Data: President First Name = Ana
# Data: President Last Name = Pino
# Data: Email Address = 619erssandiego@gmail.com
# Data: City = San Diego
# Data: State = California
# Data: Country = United States
# Data: Venue = Bridges Bar & Grill
# Data: Venue Location = 4800 Art Street
# Data: Total Fans = 20.0
# Wrote data for
#
# Processing Placemark 92:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6266742121
# Data: ﻿Fan Chapter Name = 626 FAITHFUL'S
# Data: President First Name = Isaac
# Data: President Last Name = C. De La Fuente
# Data: Email Address = 626faithfulchapter@gmail.com
# Data: City = City of Industry
# Data: State = California
# Data: Country = United States
# Data: Venue = Hacienda Heights Pizza Co.
# Data: Venue Location = 15239 E Gale Ave
# Data: Total Fans = 40.0
# Wrote data for
#
# Processing Placemark 93:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6507438522
# Data: ﻿Fan Chapter Name = Niner Empire 650 Chapter
# Data: President First Name = Vanessa
# Data: President Last Name = Corea
# Data: Email Address = 650ninerchapter@gmail.com
# Data: City = Redwood City
# Data: State = CA
# Data: Country = United States
# Data: Venue = 5th Quarter
# Data: Venue Location = 976 Woodside Rd
# Data: Total Fans = 35.0
# Data: Instagram = http://www.instagram.com/650ninerempire
# Wrote data for
#
# Processing Placemark 94:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 6199949071
# Data: ﻿Fan Chapter Name = 714 Niner Empire
# Data: President First Name = Daniel
# Data: President Last Name = Hernandez
# Data: Email Address = 714ninerempire@gmail.com
# Data: City = Oxnard
# Data: State = CA
# Data: Country = United States
# Data: Venue = Bottoms Up Tavern, 2162 West Lincoln Ave, Anaheim CA 92801
# Data: Venue Location = 3206 Lisbon Lane
# Data: Total Fans = 4.0
# Wrote data for
#
# Processing Placemark 95:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 9513704443
# Data: ﻿Fan Chapter Name = 9er Elite Niner Empire
# Data: President First Name = Penny
# Data: President Last Name = Mapes
# Data: Email Address = 9erelite@gmail.com
# Data: City = Lake Elsinore
# Data: State = California
# Data: Country = United States
# Data: Venue = Pin 'n' Pockets
# Data: Venue Location = 32250 Mission Trail
# Data: Total Fans = 25.0
# Wrote data for
#
# Processing Placemark 96:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 4806780578
# Data: ﻿Fan Chapter Name = Az 49er Faithful
# Data: President First Name = Kimberly
# Data: President Last Name = ""Kimi"" Daniel
# Data: Email Address = 9rzfan@gmail.com
# Data: City = Gilbert
# Data: State = Az
# Data: Country = United States
# Data: Venue = Fox and Hound!
# Data: Venue Location = 1017 E Baseline Rd
# Data: Total Fans = 58.0
# Wrote data for
#
# Processing Placemark 97:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 7078896983
# Data: ﻿Fan Chapter Name = Niners Winers
# Data: President First Name = A.m.
# Data: President Last Name = Early
# Data: Email Address = a.m.early@icloud.com
# Data: City = Forestville
# Data: State = Ca
# Data: Country = United States
# Data: Venue = Bars and wineries in sonoma and napa counties
# Data: Venue Location = River road
# Data: Total Fans = 25.0
# Wrote data for
#
# Processing Placemark 98:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 2144897300
# Data: ﻿Fan Chapter Name = a_49er fan
# Data: President First Name = Angel
# Data: President Last Name = Barba
# Data: Email Address = a_49erfan@aol.com
# Data: City = wylie
# Data: State = texas
# Data: Country = United States
# Data: Venue = Wylie
# Data: Venue Location = 922 cedar creek dr.
# Data: Total Fans = 12.0
# Wrote data for
#
# Processing Placemark 99:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 4153206471
# Data: ﻿Fan Chapter Name = Niner Empire Marin
# Data: President First Name = Aaron
# Data: President Last Name = Clark
# Data: Email Address = aaron.clark@ninerempiremarin.com
# Data: City = Novato
# Data: State = CA
# Data: Country = United States
# Data: Venue = Moylan's Brewery & Restaurant
# Data: Venue Location = 15 Rowland Way
# Data: Total Fans = 13.0
# Wrote data for
#
# Processing Placemark 100:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 2095344459
# Data: ﻿Fan Chapter Name = 4T9 Mob
# Data: President First Name = Angel
# Data: President Last Name = Cruz
# Data: Email Address = ac_0779@live.com
# Data: City = Modesto
# Data: State = ca
# Data: Country = United States
# Data: Venue = Jack's pizza cafe
# Data: Venue Location = 2001 Mchenry ave
# Data: Total Fans = 30.0
# Wrote data for
#
# Processing Placemark 101:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 5708529383
# Data: ﻿Fan Chapter Name = North Eastern Pennsyvania chapter
# Data: President First Name = Benjamin
# Data: President Last Name = Simon
# Data: Email Address = acuraman235@yahoo.com
# Data: City = Larksville
# Data: State = PA
# Data: Country = United States
# Data: Venue = Zlo joes sports bar
# Data: Venue Location = 234 Nesbitt St
# Data: Total Fans = 25.0
# Wrote data for
#
# Processing Placemark 102:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = 5039150229
# Data: ﻿Fan Chapter Name = PDX Frisco Fanatics
# Data: President First Name = Adam
# Data: President Last Name = Hunter
# Data: Email Address = adam@oakbrew.com
# Data: City = Portland
# Data: State = Or
# Data: Country = United States
# Data: Venue = Suki's bar and Grill
# Data: Venue Location = 2401 sw 4th ave
# Data: Total Fans = 8.0
# Wrote data for
#
# Processing Placemark 103:
# Found ExtendedData
# Found 24 Data elements
# Data: Phone Number = (408) 981-0615
# Data: ﻿Fan Chapter Name = The 101 Niner Empire
# Data: President First Name = ANDRONICO [Adrian]
# Data: President Last Name = FERNANDEZ
# Data: Email Address = adriannoel@mail.com
# Data: City = Morgan Hill
# Data: State = CA
# Data: Country = United States
# Data: Venue = Huntington Station restaurant and sports pub
# Data: Venue Location = Huntington Station restaurant and sports pub
# Data: Total Fans = 10.0
# Data: Facebook = https://www.facebook.com/THE101NINEREMPIRE/
# Wrote data for
#
# Processing Placemark 104:
# Found ExtendedData
# ...
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Joe
# Data: President Last Name = Rocha
# Data: Phone Number = 5592897293
# Data: Email Address = theeempirefaithfulfc@live.com
# Data: City = Fresno
# Data: State = California
# Data: Country = United States
# Data: Venue = Buffalo Wild Wings
# Data: Venue Location = 3065 E Shaw Ave
# Data: Total Fans = 50.0
# Wrote data for Thee Empire Faithful
#
# Processing Placemark 770:
# Found name: The Oregon Faithful
# Found address: Eugene OR United States The Side Bar Side Bar
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Jeff
# Data: President Last Name = Sutton
# Data: Phone Number = 5412063142
# Data: Email Address = theoregonfaithful@gmail.com
# Data: City = Eugene
# Data: State = OR
# Data: Country = United States
# Data: Venue = The Side Bar
# Data: Venue Location = Side Bar
# Data: Total Fans = 12.0
# Data: X (Twitter) = oregonfaithful on Twitter
# Wrote data for The Oregon Faithful
#
# Processing Placemark 771:
# Found name: The ORIGINAL Niner Empire-New Jersey Chapter
# Found address: Linden NJ United States Nuno's Pavilion 300 Roselle ave
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Charlie
# Data: President Last Name = Murphy
# Data: Phone Number = 9082475788
# Data: Email Address = theoriginalninernjchapter@gmail.com
# Data: City = Linden
# Data: State = NJ
# Data: Country = United States
# Data: Venue = Nuno's Pavilion
# Data: Venue Location = 300 Roselle ave
# Data: Total Fans = 35.0
# Wrote data for The ORIGINAL Niner Empire-New Jersey Chapter
#
# Processing Placemark 772:
# Found name: What a Rush (gold)
# Found address: Rochester NY United States The Scotch House Pub 373 south Goodman street
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Paul
# Data: President Last Name = Smith
# Data: Phone Number = 5852788246
# Data: Email Address = thescotchhouse@gmail.com
# Data: City = Rochester
# Data: State = NY
# Data: Country = United States
# Data: Venue = The Scotch House Pub
# Data: Venue Location = 373 south Goodman street
# Data: Total Fans = 15.0
# Wrote data for What a Rush (gold)
#
# Processing Placemark 773:
# Found name: Moreno Valley 49er Empire
# Found address: Moreno Vallay CA United States S Bar and Grill 23579 Sunnymead Ranch Pkwy
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Tibor
# Data: President Last Name = Belt
# Data: Phone Number = 9519029955
# Data: Email Address = tibor.belt@yahoo.com
# Data: City = Moreno Vallay
# Data: State = CA
# Data: Country = United States
# Data: Venue = S Bar and Grill
# Data: Venue Location = 23579 Sunnymead Ranch Pkwy
# Data: Total Fans = 15.0
# Data: Facebook = https://www.facebook.com/pages/Moreno-Valley-49er-Empire/220528134738022
# Wrote data for Moreno Valley 49er Empire
#
# Processing Placemark 774:
# Found name: The Niner Empire, 405 Faithfuls, Oklahoma City
# Found address: Oklahoma city OK United States Hooters NW Expressway OKC 3025 NW EXPRESSWAY
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Maria
# Data: President Last Name = Ward
# Data: Phone Number = 14054370161
# Data: Email Address = tne405faithfuls@gmail.com
# Data: City = Oklahoma city
# Data: State = OK
# Data: Country = United States
# Data: Venue = Hooters NW Expressway OKC
# Data: Venue Location = 3025 NW EXPRESSWAY
# Data: Total Fans = 25.0
# Data: Facebook = https://www.facebook.com/share/g/4RVmqumg1MQNtMSi/?mibextid=K35XfP
# Wrote data for The Niner Empire, 405 Faithfuls, Oklahoma City
#
# Processing Placemark 775:
# Found name: 707 EMPIRE VALLEY
# Found address: napa California United States Ruiz Home 696a stonehouse drive
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Tony
# Data: President Last Name = Ruiz
# Data: Phone Number = 7072971945
# Data: Email Address = tonyruiz49@gmail.com
# Data: City = napa
# Data: State = California
# Data: Country = United States
# Data: Venue = Ruiz Home
# Data: Venue Location = 696a stonehouse drive
# Data: Total Fans = 10.0
# Wrote data for 707 EMPIRE VALLEY
#
# Processing Placemark 776:
# Found name: Treasure Valley 49er Faithful
# Found address: Star ID United States The Beer Guys Saloon 10937 W. State Street
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Curt
# Data: President Last Name = Starz
# Data: Phone Number = 208-964-2981
# Data: Email Address = treasurevalley49erfaithful@gmail.com
# Data: City = Star
# Data: State = ID
# Data: Country = United States
# Data: Venue = The Beer Guys Saloon
# Data: Venue Location = 10937 W. State Street
# Data: Total Fans = 100.0
# Data: Facebook = https://www.facebook.com/TV49erFaithful
# Wrote data for Treasure Valley 49er Faithful
#
# Processing Placemark 777:
# Found name: Hampton Roads Niner Empire
# Found address: Newport news VA United States Boathouse Live 11800 Merchants Walk #100
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Nick
# Data: President Last Name = Farmer
# Data: Phone Number = (804) 313-1137
# Data: Email Address = Trickynick89@aol.com
# Data: City = Newport news
# Data: State = VA
# Data: Country = United States
# Data: Venue = Boathouse Live
# Data: Venue Location = 11800 Merchants Walk #100
# Data: Total Fans = 300.0
# Data: Facebook = https://m.facebook.com/groups/441340355910833?ref=bookmarks
# Wrote data for Hampton Roads Niner Empire
#
# Processing Placemark 778:
# Found name: Niner Empire Salem
# Found address: Salem OR United States AMF Firebird Lanes 4303 Center St NE
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Timothy
# Data: President Last Name = Stevens
# Data: Phone Number = (971) 218-4734
# Data: Email Address = tstevens1989@gmail.com
# Data: City = Salem
# Data: State = OR
# Data: Country = United States
# Data: Venue = AMF Firebird Lanes
# Data: Venue Location = 4303 Center St NE
# Data: Total Fans = 218.0
# Wrote data for Niner Empire Salem
#
# Processing Placemark 779:
# Found name: Forty Niners LA chapter
# Found address: Bell Ca United States Krazy Wings 7016 Atlantic Blvd
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Tony
# Data: Phone Number = 3234590567
# Data: Email Address = tvaladez49ers@gmail.com
# Data: City = Bell
# Data: State = Ca
# Data: Country = United States
# Data: Venue = Krazy Wings
# Data: Venue Location = 7016 Atlantic Blvd
# Data: Total Fans = 15.0
# Wrote data for Forty Niners LA chapter
#
# Processing Placemark 780:
# Found name: Red River Niner Empire
# Found address: Bossier City LA United States Walk On's Bossier City 3010 Airline Dr
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Tyra
# Data: President Last Name = Kinsey
# Data: Phone Number = (318) 268-9657
# Data: Email Address = tylkinsey@gmail.com
# Data: City = Bossier City
# Data: State = LA
# Data: Country = United States
# Data: Venue = Walk On's Bossier City
# Data: Venue Location = 3010 Airline Dr
# Data: Total Fans = 15.0
# Data: Facebook = www.facebook.com/RedRiverNinerEmpire
# Wrote data for Red River Niner Empire
#
# Processing Placemark 781:
# Found name: Ultimate 49er Empire
# Found address: Pembroke pines Florida United States Pines alehouse 11795 pine island blvd
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Nadieshda
# Data: President Last Name = Nadie Lizabe
# Data: Phone Number = 3058965471
# Data: Email Address = Ultimateninerempire@gmail.com
# Data: City = Pembroke pines
# Data: State = Florida
# Data: Country = United States
# Data: Venue = Pines alehouse
# Data: Venue Location = 11795 pine island blvd
# Data: Total Fans = 14.0
# Wrote data for Ultimate 49er Empire
#
# Processing Placemark 782:
# Found name: Utah Niner Empire
# Found address: Salt Lake City UT United States Legends Sports Pub 677 South 200 West
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Travis
# Data: President Last Name = Vallejo
# Data: Phone Number = 8014140109
# Data: Email Address = utahninerempire@gmail.com
# Data: City = Salt Lake City
# Data: State = UT
# Data: Country = United States
# Data: Venue = Legends Sports Pub
# Data: Venue Location = 677 South 200 West
# Data: Total Fans = 25.0
# Data: Facebook = https://www.facebook.com/UtahNinerEmpire
# Wrote data for Utah Niner Empire
#
# Processing Placemark 783:
# Found name: Phoenix602Faithful
# Found address: Phoenix AZ United States Galaghers 3220 E Baseline Rd
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Vincent
# Data: President Last Name = Price
# Data: Phone Number = (480) 493-9526
# Data: Email Address = vprice068@yahoo.com
# Data: City = Phoenix
# Data: State = AZ
# Data: Country = United States
# Data: Venue = Galaghers
# Data: Venue Location = 3220 E Baseline Rd
# Data: Total Fans = 20.0
# Wrote data for Phoenix602Faithful
#
# Processing Placemark 784:
# Found name: WESTSIDE 9ERS
# Found address: Carson CA United States Buffalo Wild Wings 736 E Del Amo Blvd
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Naimah
# Data: President Last Name = Williams
# Data: Phone Number = 3108979404
# Data: Email Address = Westside9ers@gmail.com
# Data: City = Carson
# Data: State = CA
# Data: Country = United States
# Data: Venue = Buffalo Wild Wings
# Data: Venue Location = 736 E Del Amo Blvd
# Data: Total Fans = 20.0
# Wrote data for WESTSIDE 9ERS
#
# Processing Placemark 785:
# Found name: Addison Point 49ner's Fans
# Found address: Addison Texas United States Addison Point Sports Grill 4578 Beltline Road
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = William
# Data: President Last Name = Kuhn
# Data: Phone Number = 4696009701
# Data: Email Address = wkpoint@gmail.com
# Data: City = Addison
# Data: State = Texas
# Data: Country = United States
# Data: Venue = Addison Point Sports Grill
# Data: Venue Location = 4578 Beltline Road
# Data: Total Fans = 288.0
# Wrote data for Addison Point 49ner's Fans
#
# Processing Placemark 786:
# Found name: 49er Forever Faithfuls
# Found address: Vancouver Wa United States Hooligans bar and grill 8220 NE Vancouver Plaza Dr, Vancouver, WA 98662
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Wayne
# Data: President Last Name = Yelloweyes-Ripoyla
# Data: Phone Number = 3605679487
# Data: Email Address = wolfhawk9506@aol.com
# Data: City = Vancouver
# Data: State = Wa
# Data: Country = United States
# Data: Venue = Hooligans bar and grill
# Data: Venue Location = 8220 NE Vancouver Plaza Dr, Vancouver, WA 98662
# Data: Total Fans = 11.0
# Wrote data for 49er Forever Faithfuls
#
# Processing Placemark 787:
# Found name: Woodland Faithful
# Found address: Woodland CA United States Mountain Mikes Pizza 171 W. Main St
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Oscar
# Data: President Last Name = Ruiz
# Data: Phone Number = 5309086004
# Data: Email Address = woodlandfaithful22@gmail.com
# Data: City = Woodland
# Data: State = CA
# Data: Country = United States
# Data: Venue = Mountain Mikes Pizza
# Data: Venue Location = 171 W. Main St
# Data: Total Fans = 30.0
# Wrote data for Woodland Faithful
#
# Processing Placemark 788:
# Found name: Niner Empire Central New York
# Found address: Cicero New York United States Tully's Good Times 7838 Brewerton Rd
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Michal
# Data: Phone Number = 3159448662
# Data: Email Address = ykeoneil@gmail.com
# Data: City = Cicero
# Data: State = New York
# Data: Country = United States
# Data: Venue = Tully's Good Times
# Data: Venue Location = 7838 Brewerton Rd
# Data: Total Fans = 6.0
# Wrote data for Niner Empire Central New York
#
# Processing Placemark 789:
# Found name: 4 Corners Faithful
# Found address: Durango CO United States Sporting News Grill 21636 Highway 160
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Anthony
# Data: President Last Name = Green
# Data: Phone Number = (970) 442-1932
# Data: Email Address = yourprince24@yahoo.com
# Data: City = Durango
# Data: State = CO
# Data: Country = United States
# Data: Venue = Sporting News Grill
# Data: Venue Location = 21636 Highway 160
# Data: Total Fans = 10.0
# Data: Facebook = https://www.facebook.com/groups/363488474141493/
# Wrote data for 4 Corners Faithful
#
# Processing Placemark 790:
# Found name: 480 Gilbert Niner Empire
# Found address: Gilbert AZ United States Panda Libre 748 N Gilbert Rd
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Elle
# Data: President Last Name = Lopez
# Data: Phone Number = (480) 708-0838
# Data: Email Address = zepolelle@gmail.com
# Data: City = Gilbert
# Data: State = AZ
# Data: Country = United States
# Data: Venue = Panda Libre
# Data: Venue Location = 748 N Gilbert Rd
# Data: Total Fans = 30.0
# Wrote data for 480 Gilbert Niner Empire
#
# Processing Placemark 791:
# Found name: Niner Empire Jalisco 49ers Guadalajara
# Found address: Guadalajara TX United States Bar Cheleros Bar CHELEROS
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Sergio
# Data: President Last Name = Hernandez
# Data: Phone Number = (331) 387-0752
# Data: Email Address = zhekografico1@gmail.com
# Data: City = Guadalajara
# Data: State = TX
# Data: Country = United States
# Data: Venue = Bar Cheleros
# Data: Venue Location = Bar CHELEROS
# Data: Total Fans = 190.0
# Data: Facebook = https://www.facebook.com/NinerEmpireJalisco49ersGuadalajara/?modal=admin_todo_tour
# Wrote data for Niner Empire Jalisco 49ers Guadalajara
#
# Processing Placemark 792:
# Found name: 49ERS Faithful of West Virginia
# Found address: Charleston WV United States The Pitch 5711 MacCorkle Ave SE
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Zachary
# Data: President Last Name = Meadows
# Data: Phone Number = 3045457327
# Data: Email Address = zmeads@live.com
# Data: City = Charleston
# Data: State = WV
# Data: Country = United States
# Data: Venue = The Pitch
# Data: Venue Location = 5711 MacCorkle Ave SE
# Data: Total Fans = 12.0
# Wrote data for 49ERS Faithful of West Virginia
#
# Processing Placemark 793:
# Found name: 49 Migos Chapter
# Found address: Saddle Brook NJ United States Midland Brewhouse 374 N Midland Ave
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Manny
# Data: President Last Name = Duarte
# Data: Phone Number = 2016971994
# Data: Email Address = Yaman053@yahoo.com
# Data: City = Saddle Brook
# Data: State = NJ
# Data: Country = United States
# Data: Venue = Midland Brewhouse
# Data: Venue Location = 374 N Midland Ave
# Data: Total Fans = 10.0
# Wrote data for 49 Migos Chapter
#
# Processing Placemark 794:
# Found name: 49ers Bay Area Faithful Social Club
# Found address: Sunnyvale CA United States Giovanni's New York Pizzeria 1127 Lawrence Expy
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Sarah
# Data: President Last Name = Wallace
# Data: Phone Number = 408-892-5315
# Data: Email Address = 49ersbayareafaithful@gmail.com
# Data: City = Sunnyvale
# Data: State = CA
# Data: Country = United States
# Data: Venue = Giovanni's New York Pizzeria
# Data: Venue Location = 1127 Lawrence Expy
# Data: Total Fans = 65.0
# Wrote data for 49ers Bay Area Faithful Social Club
#
# Processing Placemark 795:
# Found name: Niner Empire Of Indy
# Found address: Indianapolis IN United States The Bulldog Bar and Lounge 5380 N College Ave
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Jay
# Data: President Last Name = Balthrop
# Data: Phone Number = 5404245114
# Data: Email Address = Indyninerfaithful@yahoo.com
# Data: City = Indianapolis
# Data: State = IN
# Data: Country = United States
# Data: Venue = The Bulldog Bar and Lounge
# Data: Venue Location = 5380 N College Ave
# Data: Total Fans = 30.0
# Wrote data for Niner Empire Of Indy
#
# Processing Placemark 796:
# Found name: NoTT 49ers SB BANG BANG
# Found address: Goleta California United States No Town Tavern 5114 Hollister Ave
# Found ExtendedData
# Found 17 Data elements
# Data: President First Name = Jesse
# Data: President Last Name = McCue
# Data: Phone Number = 8056791423
# Data: Email Address = jessemccue@hotmail.com
# Data: City = Goleta
# Data: State = California
# Data: Country = United States
# Data: Venue = No Town Tavern
# Data: Venue Location = 5114 Hollister Ave
# Data: Total Fans = 12.0
# Data: Website = buildsbc.com
# Wrote data for NoTT 49ers SB BANG BANG
#
# Successfully processed 796 out of 797 Placemarks
# Data written to /Users/alex.liss/Documents/1_DS AI LIVE /NEW MERGED PROJECT/merged/data/49ers_fan_chapters.csv
